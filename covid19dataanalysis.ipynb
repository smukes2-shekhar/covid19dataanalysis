# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv = pd.read_csv("C:/Users/13126/Downloads/Covid19_Confirmed_dataset.csv")
corona_dataset_csv.head(100)
# Out:
#    Province/State      Country/Region      Lat     Long  1/22/20  1/23/20  \
# 0             NaN         Afghanistan  33.0000  65.0000        0        0
# 1             NaN             Albania  41.1533  20.1683        0        0
# 2             NaN             Algeria  28.0339   1.6596        0        0
# 3             NaN             Andorra  42.5063   1.5218        0        0
# 4             NaN              Angola -11.2027  17.8739        0        0
# ..            ...                 ...      ...      ...      ...      ...
# 95            NaN            Djibouti  11.8251  42.5903        0        0
# 96            NaN  Dominican Republic  18.7357 -70.1627        0        0
# 97            NaN             Ecuador  -1.8312 -78.1834        0        0
# 98            NaN               Egypt  26.0000  30.0000        0        0
# 99            NaN         El Salvador  13.7942 -88.8965        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  \
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape #returns rows and columns in the dataset respectively
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
#corona_dataset_csv.drop(["Lat","Long"],axis = 1) 
corona_dataset_csv.head(10)
#list containing the names of the columns that we want to drop and specify whether to delete rows or columns
#axis = 1 means delete columns
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc['China'][:3].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['China'].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rate = []

for i in countries:
    max_infection_rate.append(corona_dataset_aggregated.loc[i].diff().max())
corona_dataset_aggregated["max_infection_rate"] = max_infection_rate

# %%
corona_dataset_aggregated
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rate"])
corona_data
# Out:
#                     max_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0
# ...                                ...
# West Bank and Gaza                66.0
# Western Sahara                     4.0
# Yemen                              5.0
# Zambia                             9.0
# Zimbabwe                           8.0
#
# [187 rows x 1 columns]

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
hapiness_report_csv = pd.read_csv("C:/Users/13126/Downloads/worldwide_happiness_report.csv")

# %%
hapiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
unnecesary_columns = ["Overall rank", "Score", "Generosity","Perceptions of corruption"]

# %%
hapiness_report_csv.drop(unnecesary_columns,axis = 1)
# Out:
#             Country or region  GDP per capita  Social support  \
# 0                     Finland           1.340           1.587
# 1                     Denmark           1.383           1.573
# 2                      Norway           1.488           1.582
# 3                     Iceland           1.380           1.624
# 4                 Netherlands           1.396           1.522
# ..                        ...             ...             ...
# 151                    Rwanda           0.359           0.711
# 152                  Tanzania           0.476           0.885
# 153               Afghanistan           0.350           0.517
# 154  Central African Republic           0.026           0.000
# 155               South Sudan           0.306           0.575
#
#      Healthy life expectancy  Freedom to make life choices
# 0                      0.986                         0.596
# 1                      0.996                         0.592
# ...

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
#hapiness_report_csv.set_index("Country or region", inplace =True)
hapiness_report_csv
# Out:
#                           Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                              1  7.769           1.340           1.587
# Denmark                              2  7.600           1.383           1.573
# Norway                               3  7.554           1.488           1.582
# Iceland                              4  7.494           1.380           1.624
# Netherlands                          5  7.488           1.396           1.522
# ...                                ...    ...             ...             ...
# Rwanda                             152  3.334           0.359           0.711
# Tanzania                           153  3.231           0.476           0.885
# Afghanistan                        154  3.203           0.350           0.517
# Central African Republic           155  3.083           0.026           0.000
# South Sudan                        156  2.853           0.306           0.575
#
# ...

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %% [markdown]
# #### Corona Dataset :

# %%
corona_data.head()
corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
hapiness_report_csv.head()
# Out:
#                    Overall rank  Score  GDP per capita  Social support  \
# Country or region
# Finland                       1  7.769           1.340           1.587
# Denmark                       2  7.600           1.383           1.573
# Norway                        3  7.554           1.488           1.582
# Iceland                       4  7.494           1.380           1.624
# Netherlands                   5  7.488           1.396           1.522
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Finland                              0.986                         0.596
# Denmark                              0.996                         0.592
# Norway                               1.028                         0.603
# Iceland                              1.026                         0.591
# Netherlands                          0.999                         0.557
#
#                    Generosity  Perceptions of corruption
# ...

# %%
hapiness_report_csv.shape
# Out:
# (156, 8)

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
maindata = corona_data.join(hapiness_report_csv, how="inner")
maindata.head()
maindata.corr()
# Out:
#                               max_infection_rate  Overall rank     Score  \
# max_infection_rate                      1.000000     -0.244777  0.228783
# Overall rank                           -0.244777      1.000000 -0.988972
# Score                                   0.228783     -0.988972  1.000000
# GDP per capita                          0.250118     -0.802204  0.793847
# Social support                          0.191958     -0.780955  0.788591
# Healthy life expectancy                 0.289263     -0.804753  0.799893
# Freedom to make life choices            0.078196     -0.570490  0.587007
# Generosity                             -0.114635     -0.063107  0.090420
# Perceptions of corruption               0.097703     -0.389360  0.420437
#
#                               GDP per capita  Social support  \
# max_infection_rate                  0.250118        0.191958
# Overall rank                       -0.802204       -0.780955
# ...

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = maindata["GDP per capita"]
y = maindata["max_infection_rate"]
sns.scatterplot(x,np.log(y)) #for scaling

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
sns.regplot(x, np.log(y)) #showing positive slope/correlation

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate
